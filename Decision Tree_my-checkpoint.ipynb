# %% [markdown]
# ## Business Case:-Based on given features we need to find whether an employee will leave the company or not.

# %%
## Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## Loading the data
data=pd.read_csv('HR-Employee-Attrition.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ## Basic checks

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [raw]
# no null value
# std for employee count and standard hours is 0 this suggests that the value are almost same.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
## Univariate analysis
# !pip install sweetviz

# %%
import sweetviz as sv
my_report = sv.analyze(data)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
data.BusinessTravel.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
sns.countplot(x='BusinessTravel',hue='Attrition', data=data)
plt.title("Attrition wrt BusinessTravel")
plt.show()

# %% [markdown]
# ### Insight: The employess who travelled rarely more likely quit the work as compared to those travelling frequently and rarely.

# %%
sns.histplot(x='BusinessTravel',hue='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Count'>

# %%
data.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
data.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
sns.countplot(x='Department',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# ### Insight: The employees in Research and development department more likely stayed in comparison to others.

# %%
data.EducationField.value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
data.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
sns.countplot(x='EducationField',hue='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# ### Insight: The employess from human resources field are more likely to quit in comparison to others.

# %%
sns.histplot(x='EducationField',hue='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Count'>

# %%
data.EnvironmentSatisfaction.value_counts()
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
sns.countplot(x='EnvironmentSatisfaction',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
sns.boxplot(x='EnvironmentSatisfaction',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction'>

# %%
sns.barplot(y='EnvironmentSatisfaction',data=data,hue='Attrition')
# Out:
# <AxesSubplot:ylabel='EnvironmentSatisfaction'>

# %%
data.Gender.value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Gender',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Insight: Males are more likely to quit as compared to females.

# %%
sns.histplot(x='Gender',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
data.JobRole.value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='JobRole',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %% [markdown]
# ### Insight: The employees in Sales executive, Research scientist, Laboratory technician are more likely to quit as compared to others.

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='JobRole',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='Count'>

# %%
data.JobLevel.value_counts()
# Out:
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64

# %%
sns.countplot(x='JobLevel',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# ### Insight: Those employess with job level:2 are less likely to quit.

# %%
sns.histplot(x='JobLevel',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='Count'>

# %%
sns.boxplot(x='JobLevel',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobLevel'>

# %%
data.JobInvolvement.value_counts()
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %%
sns.countplot(x='JobInvolvement',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %% [markdown]
# ### Insight:Employees with Job involvement level:3 are less likely to quit.

# %%
sns.histplot(x='JobInvolvement',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='Count'>

# %%
sns.boxplot(x='JobInvolvement',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobInvolvement'>

# %%
data.JobSatisfaction.value_counts()
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %%
sns.countplot(x='JobSatisfaction',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# ### Insight: Employees job satisfaction level  at level 4 are the one who less likely quits.

# %%
sns.histplot(x='JobSatisfaction',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Count'>

# %%
sns.boxplot(x='JobSatisfaction',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction'>

# %%
data.MaritalStatus.value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
sns.countplot(x='MaritalStatus',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# ### Insight: Employees who are single are more likely to quit as compared to others.

# %%
sns.histplot(x='MaritalStatus',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Count'>

# %%
data.OverTime.value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
sns.countplot(x='OverTime',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# ### Insight: Attriton is almost equal in both scenario

# %%
sns.histplot(x='OverTime',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='Count'>

# %%
sns.histplot(x='Age',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='Age',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# ### Insight: Employees aged 34 and 35 are less likely to quit and both are at same level.

# %%
data.Education.value_counts()
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
sns.histplot(x='Education',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
sns.countplot(x='Education',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# ### Insight: Employees at education level 3 are less likely to quit.

# %%
data.RelationshipSatisfaction.value_counts()
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %%
sns.countplot(x='RelationshipSatisfaction',data=data)
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='count'>

# %%
sns.histplot(x='RelationshipSatisfaction',data=data)
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='Count'>

# %%
sns.boxplot(x='RelationshipSatisfaction',data=data)
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction'>

# %%
data.StockOptionLevel.value_counts()
# Out:
# 0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64

# %%
sns.countplot(x='StockOptionLevel',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='count'>

# %% [markdown]
# ### Insight: Employees at stock option level: 1 are less likely to quit.

# %%
sns.histplot(x='StockOptionLevel',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='Count'>

# %%
data.TotalWorkingYears.value_counts()
# Out:
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 7      81
# 1      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 11     36
# 13     36
# 21     34
# 17     33
# 2      31
# 14     31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 30      7
# 33      7
# 27      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: TotalWorkingYears, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='TotalWorkingYears',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %%
data.TrainingTimesLastYear.value_counts()
# Out:
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: TrainingTimesLastYear, dtype: int64

# %%
sns.countplot(x='TrainingTimesLastYear',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='count'>

# %% [markdown]
# ### Insight: Employees with twice training time previous year less likely quitted.

# %%
sns.histplot(x='TrainingTimesLastYear',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='Count'>

# %%
data.WorkLifeBalance.value_counts()
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
sns.countplot(x='WorkLifeBalance',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='count'>

# %% [markdown]
# ### Insight: Employees with level 3 work life balance are most like to quit.

# %%
sns.histplot(x='WorkLifeBalance',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='Count'>

# %%
data.YearsAtCompany.value_counts()
# Out:
# 5     196
# 1     171
# 3     128
# 2     127
# 10    120
# 4     110
# 7      90
# 9      82
# 8      80
# 6      76
# 0      44
# 11     32
# 20     27
# 13     24
# 15     20
# 14     18
# 22     15
# 12     14
# 21     14
# 18     13
# 16     12
# 19     11
# 17      9
# 24      6
# 33      5
# 25      4
# 26      4
# 31      3
# 32      3
# 27      2
# 36      2
# 29      2
# 23      2
# 37      1
# 40      1
# 34      1
# 30      1
# Name: YearsAtCompany, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='YearsAtCompany',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='count'>

# %% [markdown]
# ### Insight: Employees who spent only 1 year at company are more likely to quit.

# %%
sns.histplot(x='YearsAtCompany',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Count'>

# %%
data.YearsInCurrentRole.value_counts()
# Out:
# 2     372
# 0     244
# 7     222
# 3     135
# 4     104
# 8      89
# 9      67
# 1      57
# 6      37
# 5      36
# 10     29
# 11     22
# 13     14
# 14     11
# 12     10
# 15      8
# 16      7
# 17      4
# 18      2
# Name: YearsInCurrentRole, dtype: int64

# %%
sns.countplot(x='YearsInCurrentRole',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='count'>

# %% [markdown]
# ### Insight: Employees with current 2 years of role are less likely to quit.

# %%
sns.histplot(x='YearsInCurrentRole',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='Count'>

# %%
data.YearsSinceLastPromotion.value_counts()
# Out:
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: YearsSinceLastPromotion, dtype: int64

# %%
sns.countplot(x='YearsSinceLastPromotion',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='count'>

# %% [markdown]
# ### Insight: Employees having 0 promotions since last promotion are more likely to quit and are also the one who are less likely to quit.

# %%
sns.histplot(x='YearsSinceLastPromotion',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Count'>

# %%
data.YearsWithCurrManager.value_counts()
# Out:
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 15      5
# 14      5
# 16      2
# Name: YearsWithCurrManager, dtype: int64

# %%
sns.countplot(x='YearsWithCurrManager',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='count'>

# %% [markdown]
# ### Insight: Employees spending 2 years with current manager are less likely to quit.

# %%
sns.histplot(x='YearsWithCurrManager',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Count'>

# %% [markdown]
# ### Data preprocessing

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
## Manual encoding Attrition feature
## map("old value":'new value')
data.Attrition=data.Attrition.map({'Yes':1,'No':0}) ##as the target value is in yes and no hence it is changed

# %%
data.Attrition.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
## Encoding BusinessTravel, this feature told the worker who travelled frequesnlty has quited the job so let do the
##manual encoding
data.BusinessTravel=data.BusinessTravel.map({'Travel_Frequently':1,'Travel_Rarely':2,'Non-Travel':0})

# %%
data.BusinessTravel.unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
data.Department=data.Department.map({'Research & Development':2,'Sales':1,'Human Resources':0})

# %%
data.Department.unique()
# Out:
# array([1, 2, 0], dtype=int64)

# %%
data.EducationField=data.EducationField.map({'Life Sciences':5,'Medical':4,'Marketing':3,'Technical Degree':2,'Other':1,'Human Resources':0 })

# %%
data.Education.unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
## Encoding JobRole
data.JobRole=data.JobRole.map({'Laboratory Technician':8,'Sales Executive':7,'Research Scientist':6,'Sales Representative':5,
                              'Human Resources':4,'Manufacturing Director':3,'Healthcare Representative':2,'Manager':1,'Research Director':0})

# %%
data.JobRole.unique()
# Out:
# array([7, 6, 8, 3, 2, 1, 5, 0, 4], dtype=int64)

# %%
## Encoding MaritalStatus
data.MaritalStatus=data.MaritalStatus.map({'Single':2,'Married':1,'Divorced':0})

# %%
data.MaritalStatus.unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
## Encoding Gender
data.Gender=pd.get_dummies(data.Gender,drop_first=True)

# %%
## Encoding OverTime
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
data.OverTime=label.fit_transform(data.OverTime) ## we use label encoder as overtime is not showing correct relationship

# %%
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           1                 1
# 1   49          0               1        279           2                 8
# 2   37          1               2       1373           2                 2
# 3   33          0               1       1392           2                 3
# 4   27          0               2        591           2                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               5              1               1
# 1          1               5              1               2
# 2          2               1              1               4
# 3          4               5              1               5
# 4          1               4              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       0          94               3         2
# ...

# %%
data1=data[['Attrition',
 'BusinessTravel',
 'Department',
 'EducationField',
 'Gender',
 'JobRole',
 'MaritalStatus',
 'Over18',
 'OverTime']]

# %%
data2=data[['Age',
 'DailyRate',
 'DistanceFromHome',
 'EmployeeNumber',
 'HourlyRate',
 'MonthlyIncome',
 'MonthlyRate',
 'NumCompaniesWorked',
 'PercentSalaryHike',
 'TotalWorkingYears',
 'YearsAtCompany',
 'YearsInCurrentRole',
 'YearsSinceLastPromotion',
 'YearsWithCurrManager']]

# %% [markdown]
# ## Feature selection

# %%
## Checking correlation

plt.figure(figsize=(30, 30))
sns.heatmap(data2.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":15})
# Out:
# <AxesSubplot:>

# %%
data[['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours']]
# Out:
#       EmployeeCount  EmployeeNumber Over18  StandardHours
# 0                 1               1      Y             80
# 1                 1               2      Y             80
# 2                 1               4      Y             80
# 3                 1               5      Y             80
# 4                 1               7      Y             80
# ...             ...             ...    ...            ...
# 1465              1            2061      Y             80
# 1466              1            2062      Y             80
# 1467              1            2064      Y             80
# 1468              1            2065      Y             80
# 1469              1            2068      Y             80
#
# [1470 rows x 4 columns]

# %%
data.EmployeeCount.unique()
# Out:
# array([1], dtype=int64)

# %%
data.EmployeeNumber.unique()
# Out:
# array([   1,    2,    4, ..., 2064, 2065, 2068], dtype=int64)

# %%
data.Over18.unique()
# Out:
# array(['Y'], dtype=object)

# %%
data.StandardHours.unique()
# Out:
# array([80], dtype=int64)

# %%
## Removing constant features ##constant features does not help in ML model hence they are removed
data.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis="columns", inplace=True)

# %%
data.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.610884
# std       9.135373     0.367863        0.665455   403.509100     0.568893
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     2.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EnvironmentSatisfaction  \
# count       1470.000000  1470.000000     1470.000000              1470.000000
# mean           9.192517     2.912925        3.883673                 2.721769
# ...

# %% [markdown]
# ### Model Creation

# %%
## Creating independent and dependent variable
x = data.drop('Attrition', axis=1)
y = data.Attrition

# %%
## Balancing the data
from collections import Counter
from imblearn.over_sampling import SMOTE
sm=SMOTE()
print(Counter(y))
x_sm,y_sm=sm.fit_resample(x,y)
print(Counter(y_sm))
# Out:
# Counter({0: 1233, 1: 237})
# Counter({1: 1233, 0: 1233})

# %%
## preparing training and testing data  ##train test split is required for regression
from sklearn.model_selection import train_test_split



x_train, x_test, y_train, y_test = train_test_split(x_sm, y_sm, test_size=0.25, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_hat=dt.predict(x_test)

# %%
## Evalauting the model
from sklearn.metrics import accuracy_score,classification_report,f1_score
## Training score
#train_predict=dt.predict(x_train)
#cc_train=accuracy_score(y_train,train_predict)
#cc_train
##Decision tree remember the training data very well

# %%
print(classification_report(y_train,train_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       922
#            1       1.00      1.00      1.00       927
#
#     accuracy                           1.00      1849
#    macro avg       1.00      1.00      1.00      1849
# weighted avg       1.00      1.00      1.00      1849

# %%
## From above we can say,the model has learnt the training data very well.
##Decision tree always perform well on training data as compared to testing.

# %%
y_hat=dt.predict(x_test)

# %%
cc_test=accuracy_score(y_test,y_hat)
cc_test
# Out:
# 0.7811993517017828

# %%
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78       311
#            1       0.76      0.81      0.79       306
#
#     accuracy                           0.78       617
#    macro avg       0.78      0.78      0.78       617
# weighted avg       0.78      0.78      0.78       617

# %%
# The model dt is not performing very well on testing data.

# %% [markdown]
# ## Hyperparameters of DecisionTree
#
# .criterion: The function to measure the quality of a split. Supported criteria are "gini" for the Gini impurity and "entropy" for the information gain.
#
# .splitter: The strategy used to choose the split at each node. Supported strategies are "best" to choose the best split and "random" to choose the best random split.
#
# .max_depth: It tells how deep the decision tree can be.The maximum depth of the tree.Deeper the tree more split it has and it captures mopre info from data.In general a DT overfits for large depth value.The tree perfectly fits the training data and fails to generalize on testing data.
#
# .min_samples_split: The minimum number of samples required to split an internal node.Ideal range is 1 to 40.
#
# .min_samples_leaf: The minimum number of samples required to be at a leaf node.Similarr to min sample split ,this describes the minimum number of samples at the leaf,the base of tree.Ideal range is 1 to 20.

# %%
##Refer this blog for more understanding
https://towardsdatascience.com/how-to-tune-a-decision-tree-f03721801680

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report,f1_score

# %%
params = {
    "criterion":("gini", "entropy"), 
    "splitter":("best", "random"), 
    "max_depth":(list(range(1, 20))), 
    "min_samples_split":[2, 3, 4], 
    "min_samples_leaf":list(range(1, 20)), 
}


tree_clf = DecisionTreeClassifier(random_state=3)
tree_cv = GridSearchCV(tree_clf, params, scoring="f1", n_jobs=-1, verbose=3, cv=3)
tree_cv.fit(x_train,y_train)
best_params = tree_cv.best_params_
print(f"Best paramters: {best_params})")
##n_jobs=-1 tells to use all part of CPUs
# Out:
# Fitting 3 folds for each of 4332 candidates, totalling 12996 fits
# Best paramters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'})

# %%
print(f"Best paramters: {best_params})")
# Out:
# Best paramters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'})

# %%
tree_cv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
tree_cv.best_score_
# Out:
# 0.8312899976142614

# %%
dt1=DecisionTreeClassifier(criterion='gini',
                           max_depth=8,min_samples_leaf=1,
                           min_samples_split=4,splitter='random')

# %%
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_split=4, splitter='random')

# %%
y_hat1=dt1.predict(x_test)

# %%
test_accuracy=accuracy_score(y_test,y_hat1)
test_accuracy
# Out:
# 0.833063209076175

# %%
test_f1=f1_score(y_test,y_hat1)
test_f1
# Out:
# 0.8393135725429017

# %%
print(classification_report(y_test,y_hat1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83       311
#            1       0.80      0.88      0.84       306
#
#     accuracy                           0.83       617
#    macro avg       0.84      0.83      0.83       617
# weighted avg       0.84      0.83      0.83       617

# %% [markdown]
# ## RandomForest Implementation

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(n_estimators=100)
rf_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict=rf_clf.predict(x_test)

# %%
from sklearn.metrics import classification_report,f1_score
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       311
#            1       0.93      0.91      0.92       306
#
#     accuracy                           0.92       617
#    macro avg       0.92      0.92      0.92       617
# weighted avg       0.92      0.92      0.92       617

# %%
f_Score=f1_score(y_test,y_predict)
f_Score
# Out:
# 0.9172185430463576

# %% [markdown]
# ## Hyperparameter Tuning
#
# ### n_estimators = number of trees in the foreset
#
# ### max_features = max number of features considered for creating the tree.
#
# ### max_depth = max number of levels in each decision tree
#
# ### min_samples_split = min number of data points placed in a node before the node is split
#
# ### min_samples_leaf = min number of data points allowed in a leaf node
#
# ### bootstrap = method for sampling data points (with or without replacement)

# %%
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start=200, stop=2000, num=10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num=11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]


random_grid = {'n_estimators': n_estimators, 'max_features': max_features,
               'max_depth': max_depth, 'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

rf_clf1 = RandomForestClassifier(random_state=42)

rf_cv = RandomizedSearchCV(estimator=rf_clf1, scoring='f1',param_distributions=random_grid, n_iter=100, cv=3, 
                               verbose=3, random_state=42, n_jobs=-1)

rf_cv.fit(x_train, y_train)
rf_best_params = rf_cv.best_params_
print(f"Best paramters: {rf_best_params})")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best paramters: {'n_estimators': 1400, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 100})

# %%
rf_clf2 = RandomForestClassifier(**rf_best_params)
rf_clf2.fit(x_train, y_train)
y_predict=rf_clf2.predict(x_test)
f1_score=f1_score(y_test,y_predict)
f1_score
# Out:
# 0.9139072847682119

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt,filled=True)
plt.show()
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
fn=['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
       'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
       'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
       'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
       'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']
cn=['Yes','No']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(dt,
               feature_names = fn, 
               class_names=cn,
               filled = True);
#fig.savefig('imagename.png')
plt.show()
